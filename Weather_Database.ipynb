# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3f747f6af5f7178088300fcdbf789c0

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3f747f6af5f7178088300fcdbf789c0

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dingle
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | sarti
# Processing Record 6 of Set 1 | hamilton
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | mangai
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | lasa
# Processing Record 11 of Set 1 | vagur
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | port-gentil
# Processing Record 16 of Set 1 | karpogory
# Processing Record 17 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | esil
# Processing Record 22 of Set 1 | lazurne
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | vila velha
# Processing Record 25 of Set 1 | mayo
# Processing Record 26 of Set 1 | herat
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | hot springs
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | zhezkazgan
# Processing Record 32 of Set 1 | seda
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | leshukonskoye
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | oranjestad
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | kruisfontein
# Processing Record 50 of Set 1 | port lincoln
# Processing Record 51 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 52 of Set 1 | clovis
# Processing Record 53 of Set 1 | busselton
# Processing Record 54 of Set 1 | asyut
# Processing Record 55 of Set 1 | mataura
# Processing Record 56 of Set 1 | nhulunbuy
# Processing Record 57 of Set 1 | dondo
# Processing Record 58 of Set 1 | nabire
# Processing Record 59 of Set 1 | mount isa
# Processing Record 60 of Set 1 | vaini
# Processing Record 61 of Set 1 | bowen
# Processing Record 62 of Set 1 | wanaka
# Processing Record 63 of Set 1 | ushuaia
# Processing Record 64 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 65 of Set 1 | gorontalo
# Processing Record 66 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 67 of Set 1 | klamath falls
# Processing Record 68 of Set 1 | east london
# Processing Record 69 of Set 1 | bethel
# Processing Record 70 of Set 1 | auki
# Processing Record 71 of Set 1 | nikolskoye
# Processing Record 72 of Set 1 | acapulco
# Processing Record 73 of Set 1 | bambous virieux
# Processing Record 74 of Set 1 | thompson
# Processing Record 75 of Set 1 | mar del plata
# Processing Record 76 of Set 1 | puli
# Processing Record 77 of Set 1 | san quintin
# Processing Record 78 of Set 1 | palestina
# Processing Record 79 of Set 1 | opuwo
# Processing Record 80 of Set 1 | andreapol
# Processing Record 81 of Set 1 | pyaozerskiy
# Processing Record 82 of Set 1 | voineasa
# Processing Record 83 of Set 1 | snezhnogorsk
# Processing Record 84 of Set 1 | kaitangata
# Processing Record 85 of Set 1 | omboue
# Processing Record 86 of Set 1 | hithadhoo
# Processing Record 87 of Set 1 | copiapo
# Processing Record 88 of Set 1 | atar
# Processing Record 89 of Set 1 | haines junction
# Processing Record 90 of Set 1 | tasiilaq
# Processing Record 91 of Set 1 | bunbury
# Processing Record 92 of Set 1 | port hedland
# Processing Record 93 of Set 1 | mayya
# Processing Record 94 of Set 1 | port blair
# Processing Record 95 of Set 1 | kununurra
# Processing Record 96 of Set 1 | vanimo
# Processing Record 97 of Set 1 | cabo san lucas
# Processing Record 98 of Set 1 | coquimbo
# Processing Record 99 of Set 1 | kavieng
# Processing Record 100 of Set 1 | taoudenni
# Processing Record 1 of Set 2 | beckley
# Processing Record 2 of Set 2 | tateyama
# Processing Record 3 of Set 2 | luwuk
# Processing Record 4 of Set 2 | rio grande
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | benjamin constant
# Processing Record 9 of Set 2 | riyadh
# Processing Record 10 of Set 2 | owando
# Processing Record 11 of Set 2 | samarai
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | jutai
# Processing Record 15 of Set 2 | mao
# Processing Record 16 of Set 2 | tigzirt
# Processing Record 17 of Set 2 | hofn
# Processing Record 18 of Set 2 | westport
# Processing Record 19 of Set 2 | honningsvag
# Processing Record 20 of Set 2 | storm lake
# Processing Record 21 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | honiara
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | berbera
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | evensk
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | san jeronimo
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | asfi
# Processing Record 39 of Set 2 | natal
# Processing Record 40 of Set 2 | neuquen
# Processing Record 41 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | katangli
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | strezhevoy
# Processing Record 46 of Set 2 | waipawa
# Processing Record 47 of Set 2 | cape canaveral
# Processing Record 48 of Set 2 | qaqortoq
# Processing Record 49 of Set 2 | okhotsk
# Processing Record 50 of Set 2 | rawson
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | roma
# Processing Record 3 of Set 3 | campo gobierno
# Processing Record 4 of Set 3 | hornepayne
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | olinda
# Processing Record 8 of Set 3 | tigil
# Processing Record 9 of Set 3 | whitianga
# Processing Record 10 of Set 3 | sangar
# Processing Record 11 of Set 3 | russell
# Processing Record 12 of Set 3 | paciran
# Processing Record 13 of Set 3 | fujieda
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | lerwick
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | alihe
# Processing Record 18 of Set 3 | qui nhon
# Processing Record 19 of Set 3 | lichuan
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | dera ghazi khan
# Processing Record 22 of Set 3 | aksarka
# Processing Record 23 of Set 3 | acari
# Processing Record 24 of Set 3 | chadan
# Processing Record 25 of Set 3 | vardo
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | north battleford
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | sao gabriel da cachoeira
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | novopokrovskaya
# Processing Record 33 of Set 3 | batsfjord
# Processing Record 34 of Set 3 | flinders
# Processing Record 35 of Set 3 | kochi
# Processing Record 36 of Set 3 | mopti
# Processing Record 37 of Set 3 | chapais
# Processing Record 38 of Set 3 | comodoro rivadavia
# Processing Record 39 of Set 3 | manta
# Processing Record 40 of Set 3 | inverell
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | nantucket
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | husavik
# Processing Record 45 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 3 | kisangani
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | ponta delgada
# Processing Record 49 of Set 3 | yacuiba
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | manuk mangkaw
# Processing Record 2 of Set 4 | berdsk
# Processing Record 3 of Set 4 | sorata
# Processing Record 4 of Set 4 | bom jesus
# Processing Record 5 of Set 4 | cap malheureux
# Processing Record 6 of Set 4 | caxias
# Processing Record 7 of Set 4 | kismayo
# Processing Record 8 of Set 4 | kirkwall
# Processing Record 9 of Set 4 | jati
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | miranda
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | ji-parana
# City not found. Skipping...
# Processing Record 15 of Set 4 | saint anthony
# Processing Record 16 of Set 4 | prince albert
# Processing Record 17 of Set 4 | puerto madryn
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | bonavista
# Processing Record 20 of Set 4 | kolpashevo
# Processing Record 21 of Set 4 | tartus
# Processing Record 22 of Set 4 | dauphin
# Processing Record 23 of Set 4 | portland
# Processing Record 24 of Set 4 | marsabit
# Processing Record 25 of Set 4 | muros
# Processing Record 26 of Set 4 | belyy yar
# Processing Record 27 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 4 | punto fijo
# Processing Record 29 of Set 4 | chenove
# Processing Record 30 of Set 4 | japura
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 4 | castlerea
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | fairbanks
# Processing Record 37 of Set 4 | iskenderun
# Processing Record 38 of Set 4 | faya
# Processing Record 39 of Set 4 | jalu
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | shima
# Processing Record 42 of Set 4 | hambantota
# Processing Record 43 of Set 4 | sao filipe
# Processing Record 44 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 4 | ukiah
# Processing Record 46 of Set 4 | urengoy
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | lodja
# Processing Record 50 of Set 4 | razdolinsk
# Processing Record 1 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 5 | chalmette
# Processing Record 3 of Set 5 | batagay
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | lapy
# Processing Record 6 of Set 5 | demidov
# Processing Record 7 of Set 5 | charters towers
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | tarnow
# Processing Record 11 of Set 5 | onega
# Processing Record 12 of Set 5 | barra
# Processing Record 13 of Set 5 | moussoro
# Processing Record 14 of Set 5 | praya
# Processing Record 15 of Set 5 | biltine
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | port alfred
# Processing Record 21 of Set 5 | xuddur
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | warri
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | nome
# Processing Record 26 of Set 5 | harwich
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | nouadhibou
# Processing Record 29 of Set 5 | delijan
# Processing Record 30 of Set 5 | vangaindrano
# Processing Record 31 of Set 5 | gabu
# Processing Record 32 of Set 5 | kerman
# Processing Record 33 of Set 5 | bereda
# Processing Record 34 of Set 5 | mudanjiang
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | kemijarvi
# Processing Record 38 of Set 5 | bria
# Processing Record 39 of Set 5 | bogande
# Processing Record 40 of Set 5 | nawa
# Processing Record 41 of Set 5 | vestmanna
# Processing Record 42 of Set 5 | suleja
# Processing Record 43 of Set 5 | tambopata
# Processing Record 44 of Set 5 | ngunguru
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | kangaatsiaq
# Processing Record 47 of Set 5 | bhinmal
# Processing Record 48 of Set 5 | great yarmouth
# Processing Record 49 of Set 5 | lazaro cardenas
# Processing Record 50 of Set 5 | coruripe
# Processing Record 1 of Set 6 | huicheng
# Processing Record 2 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 6 | pitanga
# Processing Record 4 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 6 | bilibino
# Processing Record 6 of Set 6 | suntar
# Processing Record 7 of Set 6 | badhni kalan
# Processing Record 8 of Set 6 | urkut
# Processing Record 9 of Set 6 | ust-maya
# Processing Record 10 of Set 6 | belmonte
# Processing Record 11 of Set 6 | taicheng
# Processing Record 12 of Set 6 | norman wells
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | arlit
# Processing Record 15 of Set 6 | santa cruz del sur
# Processing Record 16 of Set 6 | pontes e lacerda
# Processing Record 17 of Set 6 | gurupi
# Processing Record 18 of Set 6 | tabuk
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | necochea
# Processing Record 21 of Set 6 | abreus
# Processing Record 22 of Set 6 | bandar
# Processing Record 23 of Set 6 | severo-kurilsk
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | minab
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | mukdahan
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | asau
# Processing Record 30 of Set 6 | redmond
# Processing Record 31 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | santa catalina
# Processing Record 34 of Set 6 | awjilah
# Processing Record 35 of Set 6 | sur
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | kalat
# Processing Record 38 of Set 6 | san patricio
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | cervo
# Processing Record 41 of Set 6 | leh
# Processing Record 42 of Set 6 | pula
# Processing Record 43 of Set 6 | port-cartier
# Processing Record 44 of Set 6 | churapcha
# Processing Record 45 of Set 6 | baykit
# Processing Record 46 of Set 6 | rosarito
# Processing Record 47 of Set 6 | hyeres
# Processing Record 48 of Set 6 | hope
# Processing Record 49 of Set 6 | sokoto
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | aras
# Processing Record 2 of Set 7 | newport
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | ancud
# Processing Record 5 of Set 7 | candido mendes
# Processing Record 6 of Set 7 | yerbogachen
# Processing Record 7 of Set 7 | broken hill
# Processing Record 8 of Set 7 | muli
# Processing Record 9 of Set 7 | novikovo
# Processing Record 10 of Set 7 | betioky
# Processing Record 11 of Set 7 | pauini
# Processing Record 12 of Set 7 | khuzdar
# Processing Record 13 of Set 7 | upernavik
# Processing Record 14 of Set 7 | waingapu
# Processing Record 15 of Set 7 | poum
# Processing Record 16 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | mujiayingzi
# Processing Record 20 of Set 7 | novyy urgal
# Processing Record 21 of Set 7 | ixtapa
# Processing Record 22 of Set 7 | saskylakh
# Processing Record 23 of Set 7 | campbellsville
# Processing Record 24 of Set 7 | lovozero
# Processing Record 25 of Set 7 | aswan
# Processing Record 26 of Set 7 | lovington
# Processing Record 27 of Set 7 | tamluk
# Processing Record 28 of Set 7 | sharan
# Processing Record 29 of Set 7 | san cristobal
# Processing Record 30 of Set 7 | alexandria
# Processing Record 31 of Set 7 | deputatskiy
# Processing Record 32 of Set 7 | longyearbyen
# Processing Record 33 of Set 7 | praia
# Processing Record 34 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 7 | matagami
# Processing Record 36 of Set 7 | san jose
# Processing Record 37 of Set 7 | dargaville
# Processing Record 38 of Set 7 | piripiri
# Processing Record 39 of Set 7 | buraydah
# Processing Record 40 of Set 7 | iranshahr
# Processing Record 41 of Set 7 | sibolga
# Processing Record 42 of Set 7 | afitos
# Processing Record 43 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 7 | port elizabeth
# Processing Record 45 of Set 7 | carlagan
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | juan lacaze
# Processing Record 48 of Set 7 | praia da vitoria
# Processing Record 49 of Set 7 | umm lajj
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | burgeo
# Processing Record 2 of Set 8 | mehamn
# Processing Record 3 of Set 8 | ostroda
# Processing Record 4 of Set 8 | hobyo
# Processing Record 5 of Set 8 | yatou
# Processing Record 6 of Set 8 | turbat
# Processing Record 7 of Set 8 | nyurba
# Processing Record 8 of Set 8 | ust-tsilma
# Processing Record 9 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 8 | islamey
# Processing Record 11 of Set 8 | aquiraz
# Processing Record 12 of Set 8 | the pas
# Processing Record 13 of Set 8 | norden
# Processing Record 14 of Set 8 | boa vista
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | ambato
# Processing Record 17 of Set 8 | hailar
# Processing Record 18 of Set 8 | kirakira
# Processing Record 19 of Set 8 | fort nelson
# Processing Record 20 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 8 | linxia
# Processing Record 22 of Set 8 | mirnyy
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | belaya gora
# Processing Record 25 of Set 8 | mackay
# Processing Record 26 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | meulaboh
# Processing Record 29 of Set 8 | yar-sale
# Processing Record 30 of Set 8 | viedma
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | bandarbeyla
# Processing Record 33 of Set 8 | araouane
# Processing Record 34 of Set 8 | livny
# Processing Record 35 of Set 8 | tommot
# Processing Record 36 of Set 8 | yulara
# Processing Record 37 of Set 8 | walvis bay
# Processing Record 38 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 8 | olafsvik
# Processing Record 40 of Set 8 | bojnurd
# Processing Record 41 of Set 8 | lata
# Processing Record 42 of Set 8 | ostrovnoy
# Processing Record 43 of Set 8 | maltahohe
# Processing Record 44 of Set 8 | anchorage
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | ubinskoye
# Processing Record 47 of Set 8 | goderich
# Processing Record 48 of Set 8 | ampanihy
# Processing Record 49 of Set 8 | motygino
# Processing Record 50 of Set 8 | ahuimanu
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | bakel
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | general roca
# Processing Record 5 of Set 9 | pictou
# Processing Record 6 of Set 9 | havoysund
# Processing Record 7 of Set 9 | inzhavino
# Processing Record 8 of Set 9 | edd
# Processing Record 9 of Set 9 | boende
# Processing Record 10 of Set 9 | teguldet
# Processing Record 11 of Set 9 | ugoofaaru
# Processing Record 12 of Set 9 | padang
# Processing Record 13 of Set 9 | bengkulu
# Processing Record 14 of Set 9 | curitibanos
# Processing Record 15 of Set 9 | puerto del rosario
# Processing Record 16 of Set 9 | statesboro
# Processing Record 17 of Set 9 | chiredzi
# Processing Record 18 of Set 9 | kharabali
# Processing Record 19 of Set 9 | jishui
# Processing Record 20 of Set 9 | florida
# Processing Record 21 of Set 9 | kavaratti
# Processing Record 22 of Set 9 | la ronge
# Processing Record 23 of Set 9 | santa rosa
# Processing Record 24 of Set 9 | nakusp
# Processing Record 25 of Set 9 | roald
# Processing Record 26 of Set 9 | sfantu gheorghe
# Processing Record 27 of Set 9 | sapa
# Processing Record 28 of Set 9 | mazagao
# Processing Record 29 of Set 9 | contamana
# Processing Record 30 of Set 9 | luorong
# Processing Record 31 of Set 9 | mapiripan
# Processing Record 32 of Set 9 | makinsk
# Processing Record 33 of Set 9 | college
# Processing Record 34 of Set 9 | salina
# Processing Record 35 of Set 9 | matara
# Processing Record 36 of Set 9 | waitati
# Processing Record 37 of Set 9 | briancon
# Processing Record 38 of Set 9 | darnah
# Processing Record 39 of Set 9 | birao
# Processing Record 40 of Set 9 | careiro da varzea
# Processing Record 41 of Set 9 | port hueneme
# Processing Record 42 of Set 9 | grand gaube
# Processing Record 43 of Set 9 | la primavera
# Processing Record 44 of Set 9 | podor
# Processing Record 45 of Set 9 | ponta pora
# Processing Record 46 of Set 9 | kirkenaer
# Processing Record 47 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 9 | antanifotsy
# Processing Record 49 of Set 9 | shenzhen
# Processing Record 50 of Set 9 | la paz
# Processing Record 1 of Set 10 | coahuayana
# Processing Record 2 of Set 10 | arman
# Processing Record 3 of Set 10 | bharthana
# Processing Record 4 of Set 10 | gat
# Processing Record 5 of Set 10 | abalak
# Processing Record 6 of Set 10 | qasigiannguit
# Processing Record 7 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 10 | loubomo
# Processing Record 9 of Set 10 | bac giang
# Processing Record 10 of Set 10 | huanan
# Processing Record 11 of Set 10 | berdigestyakh
# Processing Record 12 of Set 10 | poltavskaya
# Processing Record 13 of Set 10 | malinovskiy
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | suzun
# Processing Record 16 of Set 10 | nemuro
# Processing Record 17 of Set 10 | orbetello
# Processing Record 18 of Set 10 | nuuk
# Processing Record 19 of Set 10 | malanje
# Processing Record 20 of Set 10 | waw
# Processing Record 21 of Set 10 | rimouski
# Processing Record 22 of Set 10 | vuktyl
# Processing Record 23 of Set 10 | nueva italia
# Processing Record 24 of Set 10 | juneau
# Processing Record 25 of Set 10 | storforshei
# Processing Record 26 of Set 10 | genhe
# Processing Record 27 of Set 10 | kenai
# Processing Record 28 of Set 10 | srikakulam
# Processing Record 29 of Set 10 | axim
# Processing Record 30 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | merauke
# Processing Record 33 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 10 | wanning
# Processing Record 36 of Set 10 | clyde river
# Processing Record 37 of Set 10 | bara
# Processing Record 38 of Set 10 | buenos aires
# Processing Record 39 of Set 10 | noumea
# Processing Record 40 of Set 10 | santa cruz cabralia
# Processing Record 41 of Set 10 | pundaguitan
# Processing Record 42 of Set 10 | meadow lake
# Processing Record 43 of Set 10 | funtua
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | popondetta
# Processing Record 46 of Set 10 | bom jardim
# Processing Record 47 of Set 10 | coos bay
# Processing Record 48 of Set 10 | kibre mengist
# Processing Record 49 of Set 10 | vihti
# Processing Record 50 of Set 10 | cockburn town
# Processing Record 1 of Set 11 | sitka
# Processing Record 2 of Set 11 | rocha
# Processing Record 3 of Set 11 | bolotnoye
# Processing Record 4 of Set 11 | calama
# Processing Record 5 of Set 11 | imeni poliny osipenko
# Processing Record 6 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 11 | frolishchi
# Processing Record 8 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | paamiut
# Processing Record 11 of Set 11 | naica
# Processing Record 12 of Set 11 | ambunti
# Processing Record 13 of Set 11 | zhangye
# Processing Record 14 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | maragheh
# Processing Record 16 of Set 11 | roebourne
# Processing Record 17 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 11 | kurtamysh
# Processing Record 19 of Set 11 | saldanha
# Processing Record 20 of Set 11 | seydi
# Processing Record 21 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 11 | komsomolskiy
# Processing Record 23 of Set 11 | toora-khem
# Processing Record 24 of Set 11 | bubaque
# Processing Record 25 of Set 11 | yashan
# Processing Record 26 of Set 11 | victor harbor
# Processing Record 27 of Set 11 | kautokeino
# Processing Record 28 of Set 11 | khor
# Processing Record 29 of Set 11 | shenjiamen
# Processing Record 30 of Set 11 | dmytrivka
# Processing Record 31 of Set 11 | iskateley
# Processing Record 32 of Set 11 | bandrele
# Processing Record 33 of Set 11 | sorland
# Processing Record 34 of Set 11 | malibu
# Processing Record 35 of Set 11 | strelka
# Processing Record 36 of Set 11 | balakhta
# Processing Record 37 of Set 11 | slave lake
# Processing Record 38 of Set 11 | along
# Processing Record 39 of Set 11 | poya
# Processing Record 40 of Set 11 | sakakah
# Processing Record 41 of Set 11 | alugan
# Processing Record 42 of Set 11 | oksfjord
# Processing Record 43 of Set 11 | todos santos
# Processing Record 44 of Set 11 | ozinki
# Processing Record 45 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 11 | puerto narino
# Processing Record 47 of Set 11 | maragogi
# Processing Record 48 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 11 | taft
# Processing Record 50 of Set 11 | las vegas
# Processing Record 1 of Set 12 | katherine
# Processing Record 2 of Set 12 | zhuhai
# Processing Record 3 of Set 12 | umea
# Processing Record 4 of Set 12 | luderitz
# Processing Record 5 of Set 12 | shache
# Processing Record 6 of Set 12 | kazanskoye
# Processing Record 7 of Set 12 | doha
# Processing Record 8 of Set 12 | launceston
# Processing Record 9 of Set 12 | poronaysk
# Processing Record 10 of Set 12 | saint-joseph
# Processing Record 11 of Set 12 | lokosovo
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | ust-kuyga
# Processing Record 14 of Set 12 | baracoa
# Processing Record 15 of Set 12 | fuerte olimpo
# Processing Record 16 of Set 12 | dunedin
# Processing Record 17 of Set 12 | tautira
# Processing Record 18 of Set 12 | takoradi
# Processing Record 19 of Set 12 | taltal
# Processing Record 20 of Set 12 | savalou
# Processing Record 21 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 12 | upata
# Processing Record 23 of Set 12 | dzerzhinskoye
# Processing Record 24 of Set 12 | avera
# Processing Record 25 of Set 12 | hay river
# Processing Record 26 of Set 12 | batagay-alyta
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | valparaiso
# Processing Record 29 of Set 12 | rumonge
# Processing Record 30 of Set 12 | moose factory
# Processing Record 31 of Set 12 | vila
# Processing Record 32 of Set 12 | beisfjord
# Processing Record 33 of Set 12 | pokhara
# Processing Record 34 of Set 12 | richards bay
# Processing Record 35 of Set 12 | los llanos de aridane
# Processing Record 36 of Set 12 | garmsar
# Processing Record 37 of Set 12 | miraflores
# Processing Record 38 of Set 12 | millinocket
# Processing Record 39 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 12 | derazhnya
# Processing Record 41 of Set 12 | zabid
# Processing Record 42 of Set 12 | lodwar
# Processing Record 43 of Set 12 | montesarchio
# Processing Record 44 of Set 12 | farakka
# Processing Record 45 of Set 12 | aguimes
# Processing Record 46 of Set 12 | brus laguna
# Processing Record 47 of Set 12 | palmer
# Processing Record 48 of Set 12 | ranong
# Processing Record 49 of Set 12 | dana point
# Processing Record 50 of Set 12 | lac du bonnet
# Processing Record 1 of Set 13 | sinnamary
# Processing Record 2 of Set 13 | kiruna
# Processing Record 3 of Set 13 | nizwa
# Processing Record 4 of Set 13 | sola
# Processing Record 5 of Set 13 | esso
# Processing Record 6 of Set 13 | plettenberg bay
# Processing Record 7 of Set 13 | autazes
# Processing Record 8 of Set 13 | kandrian
# Processing Record 9 of Set 13 | talara
# Processing Record 10 of Set 13 | constantine
# Processing Record 11 of Set 13 | miracema do tocantins
# Processing Record 12 of Set 13 | cotonou
# Processing Record 13 of Set 13 | kawalu
# Processing Record 14 of Set 13 | kutum
# Processing Record 15 of Set 13 | puerto escondido
# Processing Record 16 of Set 13 | fukue
# Processing Record 17 of Set 13 | kungurtug
# Processing Record 18 of Set 13 | maxixe
# Processing Record 19 of Set 13 | emborion
# Processing Record 20 of Set 13 | dhidhdhoo
# Processing Record 21 of Set 13 | hearst
# Processing Record 22 of Set 13 | erdenet
# Processing Record 23 of Set 13 | neiafu
# Processing Record 24 of Set 13 | saint-augustin
# Processing Record 25 of Set 13 | digha
# Processing Record 26 of Set 13 | ibateguara
# Processing Record 27 of Set 13 | manzil salim
# Processing Record 28 of Set 13 | langham
# Processing Record 29 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 30 of Set 13 | krasnyy yar
# Processing Record 31 of Set 13 | touros
# Processing Record 32 of Set 13 | saint-georges
# Processing Record 33 of Set 13 | saint-ambroise
# Processing Record 34 of Set 13 | irricana
# Processing Record 35 of Set 13 | kapit
# Processing Record 36 of Set 13 | langarud
# Processing Record 37 of Set 13 | loiza
# Processing Record 38 of Set 13 | blackwater
# Processing Record 39 of Set 13 | vao
# Processing Record 40 of Set 13 | pindobacu
# Processing Record 41 of Set 13 | korla
# Processing Record 42 of Set 13 | kargat
# Processing Record 43 of Set 13 | kieta
# Processing Record 44 of Set 13 | gerash
# Processing Record 45 of Set 13 | dillon
# Processing Record 46 of Set 13 | shingu
# Processing Record 47 of Set 13 | chokurdakh
# Processing Record 48 of Set 13 | kichera
# Processing Record 49 of Set 13 | statesville
# Processing Record 50 of Set 13 | chifeng
# Processing Record 1 of Set 14 | kuytun
# Processing Record 2 of Set 14 | polyarnyy
# Processing Record 3 of Set 14 | sandwick
# Processing Record 4 of Set 14 | nattam
# Processing Record 5 of Set 14 | jacareacanga
# Processing Record 6 of Set 14 | polson
# Processing Record 7 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 8 of Set 14 | orlik
# Processing Record 9 of Set 14 | narsaq
# Processing Record 10 of Set 14 | simao
# Processing Record 11 of Set 14 | te anau
# Processing Record 12 of Set 14 | togur
# Processing Record 13 of Set 14 | pacifica
# Processing Record 14 of Set 14 | tezu
# Processing Record 15 of Set 14 | pemangkat
# Processing Record 16 of Set 14 | ballina
# Processing Record 17 of Set 14 | marzuq
# Processing Record 18 of Set 14 | guaratinga
# Processing Record 19 of Set 14 | masuguru
# Processing Record 20 of Set 14 | warrington
# Processing Record 21 of Set 14 | khomeyn
# Processing Record 22 of Set 14 | anadyr
# Processing Record 23 of Set 14 | buchmany
# Processing Record 24 of Set 14 | yumen
# Processing Record 25 of Set 14 | kolobrzeg
# Processing Record 26 of Set 14 | san carlos de bariloche
# Processing Record 27 of Set 14 | serenje
# Processing Record 28 of Set 14 | umm kaddadah
# Processing Record 29 of Set 14 | manokwari
# Processing Record 30 of Set 14 | sao gabriel
# Processing Record 31 of Set 14 | vung tau
# Processing Record 32 of Set 14 | marystown
# Processing Record 33 of Set 14 | catamayo
# Processing Record 34 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 14 | judaberg
# Processing Record 36 of Set 14 | sioux lookout
# Processing Record 37 of Set 14 | semey
# Processing Record 38 of Set 14 | pietarsaari
# Processing Record 39 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 40 of Set 14 | saurimo
# Processing Record 41 of Set 14 | antalaha
# Processing Record 42 of Set 14 | nashville
# Processing Record 43 of Set 14 | santa maria
# Processing Record 44 of Set 14 | biak
# Processing Record 45 of Set 14 | kolokani
# Processing Record 46 of Set 14 | the valley
# Processing Record 47 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 14 | zabaykalsk
# Processing Record 49 of Set 14 | el rusio
# Processing Record 50 of Set 14 | moree
# Processing Record 1 of Set 15 | pangkalanbuun
# Processing Record 2 of Set 15 | metehara
# City not found. Skipping...
# Processing Record 3 of Set 15 | sidi qasim
# City not found. Skipping...
# Processing Record 4 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 15 | kaa-khem
# Processing Record 6 of Set 15 | malartic
# Processing Record 7 of Set 15 | ayame
# Processing Record 8 of Set 15 | shreveport
# Processing Record 9 of Set 15 | laguna
# Processing Record 10 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 11 of Set 15 | ulenurme
# Processing Record 12 of Set 15 | la roche-sur-yon
# Processing Record 13 of Set 15 | verkhnyaya inta
# Processing Record 14 of Set 15 | turukhansk
# Processing Record 15 of Set 15 | port moresby
# Processing Record 16 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 15 | sao jose da coroa grande
# -----------------------------
# Data Retrieval Complete

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(100)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Dingle  10.9995  122.6711     73.22        89          40
# 1        Puerto Ayora  -0.7393  -90.3518     76.96        85          53
# 2          Bredasdorp -34.5322   20.0403     60.28        96         100
# 3           Geraldton -28.7667  114.6000     64.81        82           1
# 4               Sarti  40.1000   23.9833     57.61        80          28
# ..                ...      ...       ...       ...       ...         ...
# 95       Punta Arenas -53.1500  -70.9167     55.51        41          20
# 96           Cherskiy  68.7500  161.3000    -46.23       100          86
# 97          Carnarvon -24.8667  113.6333     73.47        73           0
# 98  Benjamin Constant  -4.3831  -70.0311     82.53        74          40
# 99             Riyadh  24.6877   46.7219     55.54        35           4
#
#     Wind Speed Country                 Date
# 0         6.87      PH  2021-12-05 22:39:19
# 1         9.62      EC  2021-12-05 22:39:19
# 2         8.48      ZA  2021-12-05 22:39:20
# 3         8.05      AU  2021-12-05 22:39:20
# 4         6.51      GR  2021-12-05 22:39:20
# ..         ...     ...                  ...
# 95       20.71      CL  2021-12-05 22:39:43
# 96        4.12      RU  2021-12-05 22:42:36
# 97       16.11      AU  2021-12-05 22:42:37
# 98        2.30      BR  2021-12-05 22:42:37
# 99        2.89      SA  2021-12-05 22:39:40
#
# [100 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
